# %% [markdown]
# # 🎨 Datenvisualisierung
#
# Willkommen im Notebook zur Datenvisualisierung mit Matplotlib und Seaborn. In diesem Tutorial werden wir erkunden, wie wir diese zwei Python-Bibliotheken nutzen können um einfache Grafiken zu erstellen.
#
# Viel Spaß beim Programmieren!! 🤗

# %% [markdown]
# zuletzt geprüft: 11.05.2023 CK

# %% [markdown]
# ## 1. Einführung 🚀

# %% [markdown]
# ### 1.1 Was Datenvisualisierung ist

# %% [markdown]
# Datenvisualisierung ist die graphische Darstellung von von Daten. Es ist ein wichtiges Werkzeug zur Datenanalyse, da es uns hilft Muster, Trends und Beziehungen in Datensätzen zu finden, die möglicherweise nicht anhand von Tabellen ersichtlich sind. Unter anderem können wir durch Datenvisualisierung schnell Ausreißer identifizieren oder die Verteilung von Werten verstehen.

# %% [markdown]
# ### 1.2 Warum Datenvisualisierung wichtig ist

# %% [markdown]
# Datenvisualisierung ist aus mehreren Gründen wichtig. Vor allem hilft sie uns die Daten zu verstehen, mit denen wir arbeiten. Durch Visualisierungen können wir schnell Trends und Muster erkennen, die wir durch das bloße Lesen von Tabellen nicht erkannt hätten.
#
# Außerdem ist Datenvisualisierung wichtig wenn man Machine Learning Projekte starten möchte. Bevor man ein Machine Learning Modell bildet, ist es wichtig den Datensatz und die zugrundeliegende Struktur zu verstehen. Visualisierung hilft uns dabei Daten in sinnvoll zu erkunden und so fundiert zu entscheiden, welche Merkmale des Datensatzes benutzt werden und wie der Datensatz vorverarbeitet werden sollte.
#
# Darüberhinaus ist Datenvisualisierung wichtig um Erkenntnisse mit anderen zu kommunizieren. Durch informative Visualisierungen können wir effektiv unsere Erkenntnisse kommunizieren und zum Beispiel unseren Vorgesetzen Empfehlungen geben, unabhängig davon ob sie das technische Hintergrundwissen haben oder nicht.

# %% [markdown]
# ### 1.3 Matplotlib und Seaborn

# %% [markdown]
# Matplotlib und Seaborn sind zwei Python-Bibliotheken die verwendet werden um Visualisierungen zu erstellen. *Matplotlib* ist eine mächtige Bibliothek mit der man viele verschiedene Visualisierungen erstellen kann - von einfachen Liniendiagrammen bis hin zu komplexen 3D-Visualisierugnen. *Searborn* ist eine Bibliothek, die auf Matplotlib basiert, die eine etwas verbesserte Schnittstelle hat um Graphen zu erstellen.

# %% [markdown]
# #### 1.3.1 Matplotlib und Seaborn installieren

# %% [markdown]
# Bevor wir Matplotlib und Seaborn benutzen könnnen, müssen wir diese Bibliotheken normalerweise installieren. Wir können diese installieren indem wir pip nutzen, einem Paket-Installations-Programm für Python. Normalerweise würde man den folgenden Code in die Programmierumgebung eingeben:
#
# ```
# pip install matplotlib
# pip install seaborn
# ```
#
# Aber in Google Colab sind die Pakete bereits installiert. Daher müssen wir das hier nicht machen.

# %% [markdown]
# #### 1.3.1 Matplotlib und Seaborn importieren

# %% [markdown]
# Um Matplotlib und Seaborn in unserem Python code zu nutzen, müssen wir sie erstmal in unser Colab-Notebook importieren.
#
# Wir können Matplotlib mit dem folgendem Code importieren:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Diese Codezeile importiert das `pyplot` Modul aus Matplotlib und gibt ihm den Namen `plt`. Wir werden diesen Alias im Verlauf unseres Codes nutzen um Visualisierungen zu erstellen.

# %% [markdown]
# Wir könnnen Seaborn mit dem foldendem Code importieren:

# %%
import seaborn as sns

# %% [markdown]
# Diese Codezeile importiert die Seaborn-Bibliothek and gibt ihr den Alias sns. Wir werden diesen Alias um Verlauf unseres Codes immmer wieder verwendeun um Visualisierungen zu erstellen. Die ausgesuchten Aliasse `sns` und `plt` sind Konvention und werden von den meisten Programmierenden verwendet.

# %% [markdown]
# ## 2. Wann welche Visualisierung verwendet wird 🤔

# %% [markdown]
# Es gibt verschiedene Arten der Datenvisualisierung. Die drei gängigsten Arten sind *Balken-, Linien- , und  Streudiagramme*. Wann welche Art typischerweise verwendet wird, wird im folgendem erklärt.
#
# 1.  **Balkendiagramme (bar plot)**: Balkendiagramme sind für den Vergleich einzelner Kategorien oder Gruppen geeignet. Sie sind besonders nützlich, wenn man den Unterschied zwischen zwei oder mehreren *Gruppen* visualisieren möchten. Du könntest beispielsweise ein Balkendiagramm verwenden, um die Verkaufszahlen für verschiedene Produkte oder die Anzahl der Auszubildenden, die eine Prüfung bestanden oder nicht bestanden haben, zu vergleichen.
#
# 2.  **Liniendiagramme (line plot)**: Liniendiagramme eignen sich zur Visualisierung von Trends im Zeitverlauf oder über verschiedene Stufen einer Variablen. Sie sind besonders nützlich, wenn man sehen möchten, wie sich eine Variable im Laufe der Zeit oder über verschiedene Kategorien hinweg verändert. Du könntesn beispielsweise ein Liniendiagramm verwenden, um zu zeigen, wie sich die Einnahmen deines Unternehmens in den letzten Jahren verändert haben.
#
# 3.  **Streudiagramme (scatter plot)**:  Streudiagramme sind nützlich, um die Beziehung zwischen zwei *kontinuierlichen Variablen* zu visualisieren. Sie sind besonders nützlich, wenn man sehen möchten, wie zwei Variablen miteinander in Beziehung stehen oder ob es eine Korrelation zwischen ihnen gibt. Du könntest beispielsweise ein Streudiagramm verwenden, um festzustellen, ob es eine Beziehung zwischen der Größe und dem Gewicht einer Person gibt.
#
# Das hier sind nur allgemeine Richtlinien und es kann Ausnahmen geben. Es ist immer eine gute Idee, die Art Deiner Daten und das, was Du kommunizieren willst, zu berücksichtigen, bevor Du dich für Art der Darstellung entscheidest.

# %% [markdown]
# ## 3. Daten laden 📥

# %% [markdown]
# Nun da wir wissen, was Matplotlib und Searborn sind, wird es Zeit, dass wir mit echten Daten arbeiten! In diesem Abschnitt werden wir drei verschiedene Datensätze in unser Notebook laden um sie im nächsten Abschnitt dan mit Matplotlib und Seaborn zu visualisieren.

# %% [markdown]
# ### 3.1 Daten von Google Drive downloaden und in Colab ablegen

# %% [markdown]
# Der erste Datensatz enthält informationen über Schüler*innen-Noten. Der zweite Datensatz enthält die Durchschnittstemperatur in Deutschland von 1750- 2020. Und schließlich der dritte Datensatz enthält Nährwertangaben für verschiedene Lebensmittel. Die Datensätze wurden für Euch vorverarbeitet und teilweise etwas vereinfacht, damit hier die Datenvisualisierung im Vordergrund stehen kann.
#
# [HIER DIE DATENSÄTZE DOWNLOADEN](https://drive.google.com/drive/folders/13WIrSKdryqwE7sfh-x4ll-IIDhCNckS8)
# Die Datensätze heißen `calories.csv`, `students_performance.csv`, und `temperature_de_decades.csv`.

# %% [markdown]
# **Hinweis**: Die ursprünglichen Versionen der Datensätze findet ihr unter den folgenden Links zu Kaggle. Kaggle ist eine Online-Plattform für Data Science-Wettbewerbe und bietet eine  umfangreiche Sammlung von öffentlich zugänglichen Datensätzen. Ihr werdet die ursprünglichen Datensätze nicht benötigen, aber sie werden hier zur Verfügugng gestellt für die Transparenz und für die besonders Neugierigen unter Euch.
#
# [Schüler:innen-Noten](https://www.kaggle.com/datasets/spscientist/students-performance-in-exams?resource=download)
#
# [Durchschnittstemperatur
# ](https://www.kaggle.com/datasets/berkeleyearth/climate-change-earth-surface-temperature-data)
#
# [Nährwertangaben](https://www.kaggle.com/datasets/haithemhermessi/usda-national-nutrient-database)

# %% [markdown]
# Nun können wir die Datensätze in unsere Colab-Umgebung laden, indem wir links auf das Ordner-Symbol ![image.png](data:image/png;base64,...) klicken und die drei Dateien in der aufkommenden Spalte ablegen.

# %% [markdown]
# ### 3.2 Daten in Python laden

# %% [markdown]
# Nachdem wir unsere Datensätze in unsere Colab-Umgebung geladen haben, können wir nun jeweils den Datensatz in unser Python-Code laden. Dazu nutzen wir Pandas (pd):

# %% [markdown]
# #### 3.2.1 Durschnittstemperatur in Deutschland laden | `temperature_de_decades.csv`

# %%
import pandas as pd

# Datensatz laden
temp_df = pd.read_csv("/content/temperature_de_decades.csv")
print(temp_df.head(7)) #zeigt ersten sieben Zeilen der Tabelle an
# Out:
#    decade  AverageTemperature
# 0    1740            4.152615
# 1    1750            7.810621
# 2    1760            7.915150
# 3    1770            8.251008
# 4    1780            7.851800
# 5    1790            8.274708
# 6    1800            7.941050

# %% [markdown]
# #### 3.2.2 Schüler*innen-Noten laden | `students_performance.csv`

# %%
# import pandas as pd # da wir Pandas bereits importiert haben, müssen wir das nicht nochmal

# Datensatz laden
performance_df = pd.read_csv("/content/students_performance.csv")
print(performance_df.head(7)) #zeigt ersten sieben Zeilen der Tabelle an
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %% [markdown]
# #### 3.2.3 Nährwertangaben laden | `calories.csv`

# %%
# import pandas as pd # da wir Pandas bereits importiert haben, müssen wir das nicht nochmal

# Datensatz laden
calories_df = pd.read_csv("/content/calories.csv")
print(calories_df.head(7)) #zeigt ersten sieben Zeilen der Tabelle an
# Out:
#    Energy_kcal  Sugar_g  Fat_g  Protein_g
# 0        441.0     7.61  21.86      34.80
# 1        260.0     0.00  13.20       5.90
# 2         96.0     0.00   1.70      20.08
# 3        368.0    29.45   4.85       8.97
# 4        370.0     1.61   1.75       7.11
# 5        207.0    21.22  11.00       3.50
# 6         79.0    13.66   0.24       0.00

# %% [markdown]
# ## 4. Daten visualisieren 🎨

# %% [markdown]
# Nachdem wir die Daten nun in die Umgebung geladen haben, können wir sie nun jeweils mit verschiedenen Diagrammen visualisieren. Wir werden im folgendem jeweils zeigen, wie man die Daten sowohl mit Matplotlib als auch mit Seaborn visualisieren kann.

# %% [markdown]
# ### 4.1 Streudiagramm | Nährwerte

# %% [markdown]
# Wir besitzen Informationen zu Nährwerten von verschiedenen Lebensmitteln. Unser Ziel ist es zu untersuchen, ob eine Korrelation zwischen dem Zuckergehalt, Fettgehalt, Proteingehalt und der Anzahl an Kalorien existiert. Dazu nutzen wir Streudiagramme.

# %%
# unsere Tabelle zu den Nährstoffen
print(calories_df.head(7)) #zeigt ersten sieben Zeilen der Tabelle an
# Out:
#    Energy_kcal  Sugar_g  Fat_g  Protein_g
# 0        441.0     7.61  21.86      34.80
# 1        260.0     0.00  13.20       5.90
# 2         96.0     0.00   1.70      20.08
# 3        368.0    29.45   4.85       8.97
# 4        370.0     1.61   1.75       7.11
# 5        207.0    21.22  11.00       3.50
# 6         79.0    13.66   0.24       0.00

# %% [markdown]
# #### 4.1.1 Streudiagramm mit Matplotlib

# %%
# Streudigramm erstellen
plt.scatter(x=calories_df['Sugar_g'], y=calories_df['Energy_kcal'])

# Beschriftung hinzufügen
plt.title('Kalorien-Zucker-Diagramm')
plt.xlabel('Zucker (g)')
plt.ylabel('Energie (kcal)')

# Diagramm anzeigen
plt.show()

# %% [markdown]
# An diesem Diagramm sehen, wir dass je mehr Zucker ein Lebensmittel erhält, desto mehr Kalorien enthält es auch. Das ist wahrscheinlich nicht überraschend. Wir werden im Folgendem untersuchen, ob es eine Korrelation gibt zwischen Zucker und Fett in Lebensmitteln:

# %%
# Streudigramm erstellen
plt.scatter(x=calories_df['Sugar_g'], y=calories_df['Fat_g'])

# Beschriftung hinzufügen
plt.title('Zucker-Fett-Diagramm')
plt.xlabel('Zucker (g)')
plt.ylabel('Fett (g)')

# Diagramm anzeigen
plt.show()

# %% [markdown]
# Es scheint keine Korrelation vorzuliegen. Zwar gibt es einige Werte, deren Fett gehalt proportional zum Zucker gehalt scheint, aber es gibt sehr viele Werte, bei denen Zucker und Fettgehalt voneinander nicht proportional abhängen.

# %% [markdown]
# Versucht euch nun selsbt an Streudiagrammen und schaut, ob ihr Korrelationen findet, zum Beispiel zwischen Fett und Protein.

# %%
# Streudigramm erstellen
# DEIN CODE HIER

# Beschriftung hinzufügen
# DEIN CODE HIER

# Diagramm anzeigen
# DEIN CODE HIER

# %% [markdown]
# #### 4.2 Streudiagramm mit Seaborn

# %%
import seaborn as sns

# Streudiagramm erstellen
sns.scatterplot(data=calories_df, x="Sugar_g", y="Energy_kcal")

# Titel hinzufügen
plt.title('Bezeihung zwischen Zucker und Energie')

# Diagramm anzeigen
plt.show()

# %% [markdown]
# Probiert nun auch mit Seaborn ein Diagramm zu ertellen. Probiert gerne wieder verschiedene Kategorien für die x- und y-Achsen aus.

# %%
import seaborn as sns

# Streudiagramm erstellen
# DEIN CODE HIER

# Titel hinzufügen
# DEIN CODE HIER

# Diagramm anzeigen
# DEIN CODE HIER

# %% [markdown]
# ### 4.2 Balkendiagramm | Schüler*innen-Noten
#
# Der Datensatz "performance_df" enthält Daten zu Geschlecht, Ethnizität, Bildungsstand der Eltern, Mittagessen, Testvorbereitungskurs sowie Noten in Mathematik, Lesen und Schreiben von Schülern. Wir möchten mithilfe von Balkendiagrammen die Verteilung der Kategorien in diesen Spalten visualisieren.

# %%
performance_df.head(7)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %% [markdown]
# #### 4.2.1 Balkendiagramm mit Matplotlib

# %% [markdown]
# Im folgendem Code wird der Datensatz `performance_df` verwendet, um die durchschnittlichen Mathematiknoten in Abhängigkeit vom elterlichen Bildungsniveau zu visualisieren.
#
# Zunächst werden die Daten gruppiert und der Durchschnitt der Mathematiknoten pro Gruppe berechnet. Anschließend wird ein Balkendiagramm erstellt, das die Durchschnittswerte für jede Gruppe anzeigt. Schließlich werden Achsenbeschriftungen und ein Titel hinzugefügt, und die x-Achsenbeschriftungen werden um 45 Grad gedreht, um eine bessere Lesbarkeit zu gewährleisten. Das Ergebnis wird abschließend als Balkendiagramm angezeigt.

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Gruppieren der Daten nach elterlichem Bildungsniveau ('parental level of education') und Berechnen des Durchschnitts der Mathematiknoten
parental_edu = performance_df.groupby('parental level of education')['math score'].mean()

# Erstellen des Balkendiagramms
plt.bar(parental_edu.index, parental_edu.values)

# Hinzufügen von Achsenbeschriftungen und Titel
plt.xlabel('elterliches Bildungsniveau')
plt.ylabel('Durchschnittliche Mathematiknote')
plt.title('Durchschnittliche Mathematiknote nach elterlichem Bildungsniveau')

# Rotiere x-Achse-Beschriftung
plt.xticks(rotation=45)

# Anzeigen des Diagramms
plt.show()

# %% [markdown]
# **Übung**: Schaue dir an, was passiert, wenn du dir statt der Mathe-Note dir die Note im Schreiben anschaust, also statt 'math_score' den 'writing_score' anschaust.

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Gruppieren der Daten nach elterlichem Bildungsniveau ('parental level of education') und Berechnen des Durchschnitts der Note im Schreiben
parental_edu = # DEIN CODE HIER

# Erstellen des Balkendiagramms
# DEIN CODE HIER

# Hinzufügen von Achsenbeschriftungen und Titel
# DEIN CODE HIER

# Rotiere x-Achse-Beschriftung
plt.xticks(rotation=45)

# Anzeigen des Diagramms
plt.show()

# %%
#@title Lösung ein/ausklappen
import pandas as pd
import matplotlib.pyplot as plt

# Gruppieren der Daten nach elterlichem Bildungsniveau ('parental level of education') und Berechnen des Durchschnitts der Schreibnoten
parental_edu = performance_df.groupby('parental level of education')['writing score'].mean()

#Erstellen des Balkendiagramms
plt.bar(parental_edu.index, parental_edu.values)

#Hinzufügen von Achsenbeschriftungen und Titel
plt.xlabel('Elterliches Bildungsniveau')
plt.ylabel('Durchschnittliche Schreibnote')
plt.title('Durchschnittliche Schreibnote nach elterlichem Bildungsniveau')

#Rotiere x-Achsen-Beschriftung
plt.xticks(rotation=45)
# Anzeigen des Diagramms
plt.show()

# %% [markdown]
# **Übung**: Schaue dir an, was passiert, wenn du statt nach elterlichem Bildungsniveau nach Gender gruppierst, d.h. statt 'parental level of education' 'gender' im Code einsetzt.

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Gruppieren der Daten nach Gender ('gender') und Berechnen des Durchschnitts der Note im Schreiben
gender = # DEIN CODE HIER

# Erstellen des Balkendiagramms
# DEIN CODE HIER

# Hinzufügen von Achsenbeschriftungen und Titel
# DEIN CODE HIER

# Rotate x-axis labels
plt.xticks(rotation=45)

# Anzeigen des Diagramms
plt.show()

# %%
#@title Lösung ein/ausklappen
import pandas as pd
import matplotlib.pyplot as plt

# Gruppieren der Daten nach Geschlecht ('gender') und Berechnen des Durchschnitts der Schreibleistungen
gender_grouped = performance_df.groupby('gender')['writing score'].mean()

# Erstellen des Balkendiagramms
plt.bar(gender_grouped.index, gender_grouped.values)

# Hinzufügen von Achsenbeschriftungen und Titel
plt.xlabel('Geschlecht')
plt.ylabel('Durchschnittliche Schreibleistung')
plt.title('Durchschnittliche Schreibleistung nach Geschlecht')

# Rotiere x-Achse-Beschriftung
plt.xticks(rotation=45)

# Anzeigen des Diagramms
plt.show()

# %% [markdown]
# Probiere gerne noch weitere Kombinationen aus und erkunde den Datensatz weiter.

# %%
# DEIN CODE HIER

# %% [markdown]
# ### 4.2 Balkendiagramm mit Seaborn

# %% [markdown]
# Wir zeigen noch kurz wie man das gleich mit Seaborn machen kann. Probiert gerne wieder verschiedene Datenvisualisierungen aus.

# %%
import pandas as pd
import seaborn as sns

# Gruppieren der Daten nach elterlichem Bildungsniveau ('parental level of education') und Berechnen des Durchschnitts der Mathematiknoten
parental_edu = performance_df.groupby('parental level of education')['math score'].mean().reset_index()

# Erstellen des Balkendiagramms
sns.barplot(x='parental level of education', y='math score', data=parental_edu)

# Hinzufügen von Achsenbeschriftungen und Titel
plt.xlabel('elterliches Bildungsniveau')
plt.ylabel('Durchschnittliche Mathematiknote')
plt.title('Durchschnittliche Mathematiknote nach elterlichem Bildungsniveau')

# Rotiere x-Achse-Beschriftung
plt.xticks(rotation=45)

# Anzeigen des Diagramms
plt.show()

# %%
# ausprobieren mit seaborn
# DEIN CODE HIER

# %% [markdown]
# ### 4.3 Liniendiagramm | Durschnittstemperatur in Deutschland
#
# Wir zeigen euch abschließen noch schnell, wie ihr mit Matplotlib und Seaborn ein Liniendiagramm erstellt, das die durchschnittliche Temperatur in Deutschland darstellt.

# %% [markdown]
# #### 4.3.1 Liniendiagramm mit Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# x- und y-Achse für das Diagramm bestimmen
x = temp_df['decade']
y = temp_df['AverageTemperature']

#  Liniendiagramm erstellen
plt.plot(x, y)

# Titel und Achsenbeschriftung bestimmen
plt.title('Durschnittstemperatur in Deutschland (1750-2020)')
plt.xlabel('Jahrzent')
plt.ylabel('Temperatur (°C)')

# Diagramm anzeigen lassen
plt.show()

# %% [markdown]
# #### 4.3.2 Liniendiagramm mit Seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Liniendiagramm erstellen
sns.lineplot(x="decade", y="AverageTemperature", data=temp_df)

# Achsensbeschriftung hinzufügen
plt.title('Durschnittstemperatur in Deutschland (1750-2020)')
plt.xlabel("Jahr")
plt.ylabel("Temperatur (Celsius)")

# Diagramm anzeigen lassen
plt.show()

# %% [markdown]
# ## 5. Abschluss 🎉

# %% [markdown]
# Herzlichen Glückwunsch zum Abschluss der Selbstlerneinheit! 🥳 Durch das Erstellen von Liniendiagrammen, Balken- und Streudiagrammen mit Matplotlib und Seaborn bist du nun besser auf Machine Learning-Projekte vorbereitet. Die Fähigkeit, Daten visuell darzustellen, ist unerlässlich für das Verständnis von Daten, die in Machine-Learning-Projekten verwendet werden. Du kannst stolz auf deine Leistung sein. Wir wünschen dir weiterhin viel Erfolg!😊
